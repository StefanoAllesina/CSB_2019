# %%
import requests # for downloading web pages
import os # to interface with the operating system
import re # regular expressions

# %%
def download_category(category = "ecology"):
    # check if directory exists 
    if os.path.exists('data/' + category) == False:
        # if the directory does not exist, create it using command line
        os.system('mkdir -p data/' + category)
    # download first page: first form the right url
    url = 'https://www.biorxiv.org/collection/' + category + '?page=0'
    # and then download it
    first_page = requests.get(url, allow_redirects=True)
    # save the first page for parsing later
    with open('data/' + category + '/0.html', 'wb') as f:
        f.write(first_page.content)
    # now try to find how many pages are available
    num_pages = re.findall(r'Go to page (\d+)', first_page.content.decode('UTF8'))[-1]
    num_pages = int(num_pages)
    # download all of the pages
    print('about to download', num_pages, 'pages')
    for i in range(1, num_pages):
        print('downloading', category, i, 'of', num_pages)
        url = 'https://www.biorxiv.org/collection/' + category + '?page=' + str(i)
        page = requests.get(url, allow_redirects=True)
        with open('data/' + category + '/' + str(i) + '.html', 'wb') as f:
            f.write(page.content)
    return None

# %%
download_category()
# Out:
# about to download 164 pages
# downloading ecology 1 of 164
# downloading ecology 2 of 164
# downloading ecology 3 of 164
# downloading ecology 4 of 164
# downloading ecology 5 of 164
# downloading ecology 6 of 164
# downloading ecology 7 of 164
# downloading ecology 8 of 164
# downloading ecology 9 of 164
# downloading ecology 10 of 164
# downloading ecology 11 of 164
# downloading ecology 12 of 164
# downloading ecology 13 of 164
# downloading ecology 14 of 164
# downloading ecology 15 of 164
# downloading ecology 16 of 164
# downloading ecology 17 of 164
# downloading ecology 18 of 164
# downloading ecology 19 of 164
# downloading ecology 20 of 164
# downloading ecology 21 of 164
# downloading ecology 22 of 164
# downloading ecology 23 of 164
# downloading ecology 24 of 164
# downloading ecology 25 of 164
# downloading ecology 26 of 164
# downloading ecology 27 of 164
# downloading ecology 28 of 164
# downloading ecology 29 of 164
# downloading ecology 30 of 164
# downloading ecology 31 of 164
# downloading ecology 32 of 164
# downloading ecology 33 of 164
# downloading ecology 34 of 164
# downloading ecology 35 of 164
# downloading ecology 36 of 164
# downloading ecology 37 of 164
# downloading ecology 38 of 164
# downloading ecology 39 of 164
# downloading ecology 40 of 164
# downloading ecology 41 of 164
# downloading ecology 42 of 164
# downloading ecology 43 of 164
# downloading ecology 44 of 164
# downloading ecology 45 of 164
# downloading ecology 46 of 164
# downloading ecology 47 of 164
# downloading ecology 48 of 164
# downloading ecology 49 of 164
# downloading ecology 50 of 164
# downloading ecology 51 of 164
# downloading ecology 52 of 164
# downloading ecology 53 of 164
# downloading ecology 54 of 164
# downloading ecology 55 of 164
# downloading ecology 56 of 164
# downloading ecology 57 of 164
# downloading ecology 58 of 164
# downloading ecology 59 of 164
# downloading ecology 60 of 164
# downloading ecology 61 of 164
# downloading ecology 62 of 164
# downloading ecology 63 of 164
# downloading ecology 64 of 164
